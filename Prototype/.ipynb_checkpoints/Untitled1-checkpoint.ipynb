# %% [markdown]
# # imports

# %%
import cv2
import matplotlib.pyplot as plt
from CaptureVideo import VideoCaptureManager
import DetectFaces
import ConnectDatabase
import StoreStudentData
import RecognitionWithDeepfaceFind as rdf
import RecognitionWithDatabase as rdb

# %% [markdown]
# # capture video using camera and extract frames

# %%
video_manager = VideoCaptureManager()

while True:
    user_input = input("Press 's' to start capture, 'q' to quit: ")
    if user_input == 's':
        capture_duration = int(input("Enter capture duration (in seconds): "))
        video_manager.start_capture(capture_duration)
    elif user_input == 'q':
        break
    else:
        print("Invalid input. Press 's' to start capture, 'q' to quit.")

frames_arr = video_manager.read_frames_from_buffer()
if frames_arr:
    print(f"original Number of frames: {len(frames_arr)}")
    frames=video_manager.reduce_frame_count(frames_arr)
    print(f"reduced number of frames:{len(frames)}")
else:
    print("No frames captured.")

# %% [markdown]
# # extract frames from stored video

# %%
video_manager = VideoCaptureManager()
frames_arr=video_manager.read_video()
print(len(frames_arr))
frames=video_manager.reduce_frame_count(frames_arr)
print(f"reduced number of frames:{len(frames)}")
img = frames_arr[0]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# 576
# reduced number of frames:192

# %% [markdown]
# # detect faces

# %%
detected_faces1=DetectFaces.detect_faces(frames)
print(len(detected_faces1))
detected_faces=DetectFaces.reduce_count(detected_faces1)
print("after deleting similar faces:",len(detected_faces))
# Out:
# 15
# after deleting similar faces: 12

# %% [markdown]
# # recognition without db

# %%
rdf.recognize(detected_faces)
# Out:
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  4.459824323654175  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.10476207733154297  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.09084630012512207  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.09001278877258301  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.09389328956604004  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.0943293571472168  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.09588050842285156  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.08700346946716309  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.09275555610656738  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.0950014591217041  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12227416038513184  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.08644771575927734  seconds
# 0 _  Data/known_faces\Devanarayan_S_R/Devanarayan_S_R.jpg
# 1 _  Data/known_faces\Amal_G/Amal_G.jpg
# 2 _  Data/known_faces\Ardra/Ardra.jpg
# Unknown Face detected
# 4 _  Data/known_faces\Devanarayan_S_R/Devanarayan_S_R.jpg
# 5 _  Data/known_faces\Amal_G/Amal_G.jpg
# 6 _  Data/known_faces\Ardra/Ardra.jpg
# Unknown Face detected
# 8 _  Data/known_faces\Amal_G/Amal_G.jpg
# 9 _  Data/known_faces\Ardra/Ardra.jpg
# 10 _  Data/known_faces\Devanarayan_S_R/Devanarayan_S_R.jpg
# Unknown Face detected

# %% [markdown]
# # recognition with db

# %%
#StoreStudentData.store_student_data()
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# 100%|██████████████████████████████████████████████████████████████████████████████████| 52/52 [00:32<00:00,  1.58it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 52/52 [00:00<00:00, 606.52it/s]

# %%
rdb.recognize(detected_faces)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# 0   Data\known_faces\Devanarayan_S_R\Devanarayan_S_R1.jpg
# 1   Data\known_faces\Amal_G\Amal_G.jpg
# 2   Data\known_faces\Ardra\Ardra.jpg
# 3   Data\known_faces\A_Nafih\A_Nafih.jpg
# 4   Data\known_faces\Devanarayan_S_R\Devanarayan_S_R1.jpg
# 5   Data\known_faces\Amal_G\Amal_G.jpg
# 6  no matches
# 7   Data\known_faces\Ameeza\Ameeza2.jpg
# 8   Data\known_faces\Amal_G\Amal_G.jpg
# 9  no matches
# 10   Data\known_faces\Devanarayan_S_R\Devanarayan_S_R1.jpg
# 11   Data\known_faces\Ameeza\Ameeza2.jpg
