# %%
import cv2
import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
import os
from deepface import DeepFace as df
#from retinaface import RetinaFace as m
#from PIL import Image
#import imagehash
import pandas as pd
# from pymongo import MongoClient
# from deepface.commons import functions
# from tqdm import tqdm
import mediapipe as mp

# %%
video = cv2.VideoCapture('Data/Video/input2.MOV')
count = 0
frames_arr = []
while video.isOpened():
    ret, frame = video.read()

    if not ret:
        break
    frames_arr.append(frame)                                         # Frames stored in frames_arr
    count += 1
video.release()
print(len(frames_arr), count)


img = frames_arr[0]
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
# Out:
# 576 576

# %%
# %%time
#remove similar frames
frames = []
frames.append(frames_arr[0])
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
for i in range(1, len(frames_arr)):
    keypoints1, descriptors1 = orb.detectAndCompute(frames[-1], None)
    keypoints2, descriptors2 = orb.detectAndCompute(frames_arr[i], None)
    matches = bf.match(descriptors1, descriptors2)
    
    #matches = sorted(matches, key=lambda x: x.distance)
    
    if len(matches) < 200:
        frames.append(frames_arr[i])
print(len(frames))
# Out:
# 55
# CPU times: total: 43.2 s
# Wall time: 47.6 s

# %%
#store in folder
output_folder='Data/intermediate_results/original_frames'
for i, frame in enumerate(frames):
        cv2.imwrite(os.path.join(output_folder, f'frame_{i}.jpg'), frame)

# %%
#remove blurred_frames

def calculate_blurriness(frame):
    gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    return cv2.Laplacian(gray, cv2.CV_64F).var()

def remove_blurred_frames(frames, threshold=60):
    sharp_frames = []
    count=0
    for i, frame in enumerate(frames):
        sharpness = calculate_blurriness(frame)
        print("frame",count," ",sharpness)
        count+=1
        if sharpness > threshold:
            sharp_frames.append(frame)
            
    return sharp_frames


# Adjust the threshold value as per your requirement
sharp_frames = remove_blurred_frames(frames, threshold=60)

# Now sharp_frames will contain the list of frames without blurred ones, and they will be saved in the current directory.
# Out:
# frame 0   78.94734519671995
# frame 1   63.02553382286394
# frame 2   57.861822432225324
# frame 3   34.55660590275453
# frame 4   45.47807095407148
# frame 5   50.68930871832996
# frame 6   52.04490643102258
# frame 7   54.566823165886355
# frame 8   67.30231555959443
# frame 9   79.04820447679683
# frame 10   61.9537287679111
# frame 11   56.76148659997263
# frame 12   50.850284529317264
# frame 13   52.199099140383886
# frame 14   45.31094461423563
# frame 15   46.793665495944964
# frame 16   47.251553331311804
# frame 17   45.36214786117407
# frame 18   47.17820265734265
# frame 19   33.563417449643254
# frame 20   50.196707173410466
# frame 21   20.893371335769366
# frame 22   32.992491131900664
# frame 23   28.372194728493508
# frame 24   37.6731886359144
# frame 25   46.81697995025259
# frame 26   52.93818034285604
# frame 27   59.978525930197726
# frame 28   58.365130135399994
# frame 29   62.21980753701081
# frame 30   61.29460448109028
# frame 31   58.20891433139496
# frame 32   41.49866296094522
# frame 33   56.02044991347702
# frame 34   51.52979839226552
# frame 35   57.46941639498906
# frame 36   52.46407261147205
# frame 37   60.91275210731738
# frame 38   61.01786104618533
# frame 39   52.60667677374225
# frame 40   60.129050413027585
# frame 41   69.29716000860441
# frame 42   67.827592506054
# frame 43   69.74258824755901
# frame 44   61.91755449428038
# frame 45   75.23408126222913
# frame 46   67.2191241457832
# frame 47   72.50664737651994
# frame 48   57.24698492775935
# frame 49   52.34860767123794
# frame 50   52.94297308992404
# frame 51   48.50467349187605
# frame 52   42.98724338777434
# frame 53   37.46338331162357
# frame 54   56.270852350176334

# %%
output_folder='Data/intermediate_results/sharp_frames'
for i, frame in enumerate(frames):
        cv2.imwrite(os.path.join(output_folder, f'frame_{i}.jpg'), frame)

# %%
print(len(sharp_frames))
# Out:
# 17

# %%
#detecting faces from sharp_frames
detected_faces = []
img = sharp_frames[0]
mp_face_detction = mp.solutions.face_detection
for frame in sharp_frames:
    with mp_face_detction.FaceDetection(model_selection = 1, min_detection_confidence = 0.5) as face_detection:
        results = face_detection.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        for detection in results.detections:
            box = detection.location_data.relative_bounding_box
            x_start, y_start = int(box.xmin * img.shape[1]), int(box.ymin * img.shape[0])
            x_end, y_end = int((box.xmin + box.width) * img.shape[1]), int((box.ymin + box.height) * img.shape[0])

            if x_start < 0 or y_start < 0:
                continue

            face = frame[y_start:y_end, x_start:x_end]
            face = cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
            detected_faces.append(face)
print(len(detected_faces))
# Out:
# 85

# %%
output_folder='Data/intermediate_results/detected_faces'
for i, face in enumerate(detected_faces):
        face=cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
        cv2.imwrite(os.path.join(output_folder, f'face_{i}.jpg'), face)

# %%
#REMOVING SIMILAR FACES
faces = []
faces.append(cv2.convertScaleAbs(detected_faces[0]))
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
for i in range(1, len(detected_faces)):
    img2 = cv2.convertScaleAbs(detected_faces[i])

    

    keypoints1, descriptors1 = orb.detectAndCompute(faces[-1], None)
    keypoints2, descriptors2 = orb.detectAndCompute(img2, None)

    if descriptors2 is None:
        
        continue

    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    matches = bf.match(descriptors1, descriptors2)

    #matches = sorted(matches, key=lambda x: x.distance)

    if len(matches) < 200:
        faces.append(detected_faces[i])

# detected_faces[:]=faces[:]
print(len(faces))
# Out:
# 85

# %%
#REMOVING BLURRED FACES
def calculate_blurriness(face):
    gray = cv2.cvtColor(face, cv2.COLOR_RGB2GRAY)
    return cv2.Laplacian(gray, cv2.CV_64F).var()

def remove_blurred_faces(faces, threshold=40):
    sharp_faces = []
    count=0
    for i, face in enumerate(faces):
        sharpness = calculate_blurriness(face)
        print("face",count," ",sharpness)#printing sharpness of each face
        count+=1
        if sharpness > threshold:
            sharp_faces.append(face)
            
    return sharp_faces


# Adjust the threshold value as per your requirement
sharp_faces = remove_blurred_faces(faces, threshold=40)
# Out:
# face 0   37.01931159898081
# face 1   44.26157404388936
# face 2   88.67778472380046
# face 3   28.54214586309424
# face 4   62.27838896462757
# face 5   44.19507949358352
# face 6   79.4313764452561
# face 7   29.032330400629373
# face 8   18.738414189127624
# face 9   28.761954470033178
# face 10   33.27517293201243
# face 11   35.666318797501866
# face 12   48.59068423867411
# face 13   65.7001496526131
# face 14   36.82114249005028
# face 15   27.38426322558147
# face 16   37.357542718940564
# face 17   49.48696592738888
# face 18   45.95348832336329
# face 19   38.404240278609244
# face 20   34.31831198818719
# face 21   46.288117936339326
# face 22   33.49186770180451
# face 23   33.663033426848685
# face 24   33.223619109261186
# face 25   19.449384294926112
# face 26   20.903851266231054
# face 27   34.470158899770915
# face 28   21.570896464851888
# face 29   22.870620047194823
# face 30   15.887639518164848
# face 31   14.747513572002601
# face 32   16.94939848220245
# face 33   32.954820986981794
# face 34   24.508180366886688
# face 35   24.196085043502396
# face 36   26.1949427203461
# face 37   43.159776923559846
# face 38   30.03893056083113
# face 39   38.94696248098766
# face 40   39.98256914314064
# face 41   35.739915866350046
# face 42   28.37504882660255
# face 43   40.68246768239776
# face 44   29.68628727933567
# face 45   32.031072377151574
# face 46   26.962347390860778
# face 47   45.16794367283789
# face 48   28.645394999938304
# face 49   33.376899389323036
# face 50   32.382122434977575
# face 51   41.183510147343455
# face 52   46.883990627441136
# face 53   46.47651806399836
# face 54   37.243782244329964
# face 55   43.23593280113752
# face 56   59.281201320215146
# face 57   60.41786014617284
# face 58   65.35617142671356
# face 59   67.8248201805098
# face 60   27.551348238482387
# face 61   44.94540884252961
# face 62   77.16691768646868
# face 63   65.25465303673239
# face 64   68.51808786886217
# face 65   58.88689301440411
# face 66   37.97444902602502
# face 67   45.652007567195476
# face 68   56.40911691304405
# face 69   67.31417886037069
# face 70   53.24876696522173
# face 71   51.32055376470089
# face 72   43.15468814772601
# face 73   50.47508800001707
# face 74   45.01737159287486
# face 75   53.418809613251724
# face 76   34.16419084396343
# face 77   9.304123103704825
# face 78   26.418545447659824
# face 79   33.39407058150878
# face 80   26.0301977694666
# face 81   30.150936106333226
# face 82   37.959525282795944
# face 83   51.12426363787721
# face 84   9.839568846679983

# %%
plt.imshow(faces[1])

# %%
output_folder='Data/intermediate_results/sharp_faces'
for i, face in enumerate(sharp_faces):
        face=cv2.cvtColor(face,cv2.COLOR_BGR2RGB)
        cv2.imwrite(os.path.join(output_folder, f'face_{i}.jpg'), face)

# %%
len(sharp_faces)
# Out:
# 36

# %%
models=[]
res=[]
present=[]
for i in range(len(sharp_faces)):
    model=df.find(img_path=sharp_faces[i],db_path='Data/known_faces',model_name="Facenet",distance_metric="euclidean",enforce_detection=False,normalization="Facenet",detector_backend='opencv')
    models.append(model)
print()
count = 0
for model in models:
    if len(model[0]) > 0:
        name=model[0]['identity'].values[0].split('\\')[-1].split('/')[-1].split('.')[-2]
        print(count , "_ ", name)
        if name not in present:
            present.append(name)
    else:
        print('Unknown Face detected')
    count += 1
# Out:
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.8355720043182373  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1639413833618164  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15303778648376465  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15325331687927246  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14867687225341797  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13774943351745605  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1527879238128662  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1343526840209961  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15943121910095215  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15804386138916016  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17618918418884277  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15912342071533203  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15523552894592285  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17162013053894043  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.18247294425964355  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.19529318809509277  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.19582152366638184  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16180896759033203  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17843413352966309  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16884684562683105  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15678834915161133  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15082550048828125  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1650218963623047  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1519787311553955  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1886613368988037  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.24224495887756348  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17188429832458496  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17506694793701172  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15372085571289062  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1463770866394043  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14548921585083008  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16318750381469727  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.20062971115112305  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.19345784187316895  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.20168733596801758  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16999602317810059  seconds
#
# 0 _  Amal_G
# 1 _  Ardra
# 2 _  Ardra
# 3 _  Devanarayan_S_R
# Unknown Face detected
# 5 _  Ardra
# 6 _  Anusree
# 7 _  Ardra
# Unknown Face detected
# 9 _  Anusree
# Unknown Face detected
# 11 _  Vyshna_S
# Unknown Face detected
# 13 _  Akshay_P
# 14 _  Yadu_Krishna
# Unknown Face detected
# 16 _  Thejus_M
# 17 _  Akshay_P
# 18 _  Ajmila_Shada
# 19 _  Vyshna_S
# Unknown Face detected
# 21 _  Akshay_P
# 22 _  Ajmila_Shada
# 23 _  Yadu_Krishna
# 24 _  Akshay_P
# 25 _  Ajmila_Shada
# Unknown Face detected
# Unknown Face detected
# Unknown Face detected
# 29 _  Akshay_P
# 30 _  Ajmila_Shada
# Unknown Face detected
# Unknown Face detected
# Unknown Face detected
# 34 _  Arjun_P_J
# Unknown Face detected

# %%
plt.imshow(sharp_faces[8])
