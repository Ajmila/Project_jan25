# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
from deepface import DeepFace as df
from retinaface import RetinaFace as m
from PIL import Image
import imagehash
import pandas as pd

# %%
image = cv2.imread("Data/img1.jpg")

# %%
plt.imshow(frames[49])

# %%
img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
#making copies
frames=[]
for i in range(50):
    frames.append(img)

# %%
# %%time
detected_faces = []
count = 1
for frame in frames:
    obj = m.detect_faces(frame)
    if isinstance(obj, dict):
        for key in obj.keys():
            faceid = obj[key]
            area = faceid['facial_area']
            x1,y1,x2,y2=area
            extracted_face=frame[y1:y2,x1:x2]
            #extracted_face=cv2.cvtColor(extracted_face,cv2.COLOR_BGR2RGB)
            detected_faces.append(extracted_face)
print(len(detected_faces))
plt.imshow(detected_faces[0])
# Out:
# 250
# CPU times: total: 11min 5s
# Wall time: 2min 38s

# %%
faces = []
faces.append(cv2.convertScaleAbs(detected_faces[0]))
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
for i in range(1, len(detected_faces)):
    img2 = cv2.convertScaleAbs(detected_faces[i])

    

    keypoints1, descriptors1 = orb.detectAndCompute(faces[-1], None)
    keypoints2, descriptors2 = orb.detectAndCompute(img2, None)

    if descriptors2 is None:
        
        continue

    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

    matches = bf.match(descriptors1, descriptors2)

    #matches = sorted(matches, key=lambda x: x.distance)

    if len(matches) < 200:
        faces.append(detected_faces[i])

detected_faces[:]=faces[:]
print(len(detected_faces))

plt.imshow(detected_faces[2])
# Out:
# 250

# %%
models=[]
res=[]

for i in range(len(detected_faces)):
    model=df.find(img_path=detected_faces[i],db_path='Data/known_faces',model_name="Facenet",distance_metric="euclidean",enforce_detection=False,normalization="Facenet")
    models.append(model)
print()
# Out:
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.6542375087738037  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1407756805419922  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16954898834228516  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16548728942871094  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1565399169921875  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14604902267456055  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1359872817993164  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1321859359741211  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15103435516357422  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1476738452911377  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15462636947631836  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13947033882141113  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14376020431518555  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14267277717590332  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13898372650146484  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14200496673583984  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14081215858459473  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1308145523071289  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14067745208740234  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14998626708984375  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1471242904663086  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13858604431152344  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14210247993469238  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17252302169799805  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1649942398071289  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15526509284973145  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17287969589233398  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15103602409362793  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15581083297729492  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14361882209777832  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14964747428894043  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14333724975585938  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14052152633666992  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14080548286437988  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13927555084228516  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14253020286560059  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1310114860534668  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17225909233093262  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17168164253234863  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15479326248168945  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13709187507629395  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14324235916137695  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13545703887939453  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1297767162322998  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1358470916748047  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13501763343811035  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13200616836547852  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1295783519744873  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13700103759765625  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13027071952819824  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1357877254486084  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1317431926727295  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13189482688903809  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13805913925170898  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13549017906188965  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1358633041381836  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13255715370178223  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12825393676757812  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14353632926940918  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15149331092834473  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15676450729370117  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1532289981842041  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1451561450958252  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1414930820465088  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1448657512664795  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1619095802307129  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16332316398620605  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14765191078186035  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16003680229187012  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1482388973236084  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14643168449401855  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13765573501586914  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13385868072509766  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14836764335632324  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15454673767089844  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13241910934448242  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13234424591064453  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12317776679992676  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13443684577941895  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1317451000213623  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14090800285339355  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13129782676696777  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1278395652770996  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12410306930541992  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12893414497375488  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14296364784240723  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1343684196472168  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13027501106262207  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13850617408752441  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13845086097717285  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1356818675994873  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13593006134033203  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13978242874145508  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13336801528930664  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1366863250732422  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1381685733795166  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12900090217590332  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14636707305908203  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1627330780029297  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15182852745056152  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16258931159973145  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1651630401611328  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1609656810760498  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16217446327209473  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15750408172607422  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15790748596191406  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14732956886291504  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1472182273864746  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1510453224182129  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14528703689575195  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15043115615844727  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14554262161254883  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15040874481201172  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14866256713867188  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1420903205871582  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13696694374084473  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14501667022705078  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1428840160369873  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14535737037658691  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13791418075561523  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13689208030700684  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13217663764953613  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.130263090133667  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13000798225402832  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14141106605529785  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16083216667175293  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15975499153137207  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15723586082458496  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16348791122436523  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16199898719787598  seconds
# ...
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14244771003723145  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13780951499938965  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1447737216949463  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1396160125732422  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14641737937927246  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13701868057250977  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13943123817443848  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1367955207824707  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1624298095703125  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17046880722045898  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16583251953125  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16612911224365234  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17955851554870605  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.18004608154296875  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16508960723876953  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.154616117477417  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1627185344696045  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1616532802581787  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16599059104919434  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1721663475036621  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15985107421875  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15293002128601074  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.142103910446167  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16456937789916992  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17041850090026855  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.17563724517822266  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16785764694213867  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16416025161743164  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16653180122375488  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.15221166610717773  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1411283016204834  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14842891693115234  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14653801918029785  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1625838279724121  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16458463668823242  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16655206680297852  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.16812682151794434  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1633305549621582  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14951324462890625  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.1387312412261963  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14782166481018066  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.14164376258850098  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.13674354553222656  seconds
# WARNING: Representations for images in Data/known_faces folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  54  representations found in  representations_facenet.pkl
# find function lasts  0.12963342666625977  seconds

# %%
count = 0
for model in models:
    if len(model[0]) > 0:
        print(count , "_ ", model[0]['identity'].values[0])
    else:
        print('Unknown Face detected')
    count += 1
# Out:
# 0 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 3 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 4 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 5 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 8 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 9 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 10 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 13 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 14 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 15 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 18 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 19 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 20 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 23 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 24 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 25 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 28 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 29 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 30 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 33 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 34 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 35 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 38 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 39 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 40 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 43 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 44 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 45 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 48 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 49 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 50 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 53 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 54 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 55 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 58 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 59 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 60 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 63 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 64 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 65 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 68 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 69 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 70 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 73 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 74 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 75 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 78 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 79 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 80 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 83 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 84 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 85 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 88 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 89 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 90 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 93 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 94 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 95 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 98 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 99 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 100 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 103 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 104 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 105 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 108 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 109 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 110 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 113 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 114 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 115 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 118 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 119 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 120 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 123 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 124 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 125 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 128 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 129 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 130 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 133 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 134 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 135 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 138 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 139 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 140 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 143 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 144 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 145 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 148 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 149 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 150 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 153 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 154 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 155 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 158 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 159 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 160 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 163 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 164 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 165 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 168 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 169 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 170 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 173 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 174 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 175 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 178 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 179 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 180 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 183 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 184 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 185 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 188 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 189 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 190 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 193 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 194 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 195 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 198 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 199 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 200 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 203 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 204 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 205 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 208 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 209 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 210 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 213 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 214 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 215 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 218 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 219 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 220 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 223 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 224 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 225 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 228 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 229 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 230 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 233 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 234 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 235 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 238 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 239 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 240 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 243 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 244 _  Data/known_faces\Ameeza/Ameeza1.jpg
# 245 _  Data/known_faces\Anusree/Anusree.jpg
# Unknown Face detected
# Unknown Face detected
# 248 _  Data/known_faces\Ajmila_Shada/Ajmila_Shada.jpg
# 249 _  Data/known_faces\Ameeza/Ameeza1.jpg

# %%
plt.imshow(detected_faces[4])

# %%
plt.imshow(detected_faces[3])

# %%
plt.imshow(detected_faces[1])

# %%
plt.imshow(detected_faces[0])

# %%
plt.imshow(detected_faces[2])
